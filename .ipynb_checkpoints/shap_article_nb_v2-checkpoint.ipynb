# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import shap
import warnings

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor

warnings.filterwarnings('ignore')
plt.ioff()

# %% [markdown]
# ## Reading and Preprocessing

# %%
df = pd.read_csv("insurance.csv")
rating_factors_col = list(df.columns[:-1])
claims_col = df.columns[-1]

# %%
num_features = list(df[rating_factors_col].select_dtypes(include=["int64", "float64"]).columns)
cat_features = [col for col in rating_factors_col if col not in num_features]

# %%
preprocesser = ColumnTransformer(
    transformers = [
        ("numerical", "passthrough", num_features),
        ("categorical", OneHotEncoder(sparse=False, handle_unknown="ignore"), cat_features)
    ]
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
            df[rating_factors_col],
            df[claims_col],
            test_size=0.2,
            random_state=123
        )

# %%
ohe_categories = preprocesser.fit(X_train).named_transformers_["categorical"].categories_
ohe_categories_concat = [f"{col}__{val}" for col, vals in zip(cat_features, ohe_categories) for val in vals]
rating_factors_encoded = num_features + ohe_categories_concat

# %% [markdown]
# ## Building the Pipeline

# %%
hyper_parameters = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "ls"
}


param_grid = {
    "model__max_depth": [80, 90, 100, 110],
    "model__max_features": [2, 3],
    "model__min_samples_leaf": [3, 4, 5],
    "model__min_samples_split": [8, 10, 12],
    "model__n_estimators": [100, 200, 300, 1000]
}


lr_model = Pipeline([("preprocesser", preprocesser), ("model", LinearRegression())])
gbm_model = Pipeline([("preprocesser", preprocesser), ("model", GradientBoostingRegressor())])

# %% [markdown]
# ## Linear Regression Model

# %%
lr_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocesser',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['age', 'bmi', 'children']),
#                                                  ('categorical',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('model', LinearRegression())])

# %%
lr_pred = lr_model.predict(X_test)
lr_mse = mean_squared_error(y_test, lr_pred)
lr_r2 = r2_score(y_test, lr_pred)

# %%
coeffs = zip(rating_factors_encoded, lr_model.named_steps["model"].coef_)
print("Model coefficients: \n")
for k, v in coeffs:
    print(k, "=", np.round(v, 2))
print("intercept: {}".format(np.round(lr_model.named_steps["model"].intercept_, 2)))
print("rmse: {}".format(np.sqrt(lr_mse)))
print("r^2: {}".format(lr_r2))
# Out:
# Model coefficients:
#
# age = 255.65
# bmi = 342.68
# children = 451.59
# sex__female = 41.72
# sex__male = -41.72
# smoker__no = -11750.51
# smoker__yes = 11750.51
# region__northeast = 619.71
# region__northwest = 200.49
# region__southeast = -413.56
# region__southwest = -406.64
# intercept: -741.39
# rmse: 5527.42593044226
# r^2: 0.8001744488359046

# %% [markdown]
# ### SHAP results

# %%
shap_lr_df = pd.DataFrame(lr_model.named_steps["preprocesser"].transform(X_train), columns=rating_factors_encoded)

# %%
# PDP for linear model
# Write function plot_pdp

feature = "bmi"
shap.plots.partial_dependence(
    feature, 
    lr_model.named_steps["model"].predict,
    shap_lr_df,
    ice=False,
    model_expected_value=True, 
    feature_expected_value=True
)

# %%
# Masker method masks out features by integrating over the given background data
# Recall that the SHAP approach requires the 2^F power set of models 
background = shap.maskers.Independent(shap_lr_df, max_samples=2000)

# Instantiate a linear explainer object with the SLR model and independent masker
explainer = shap.LinearExplainer(lr_model.named_steps["model"], background)
shap_values = explainer(shap_lr_df)

# %%
idx = 30
shap.plots.waterfall(shap_values[idx], max_display=14, show=False)
fig = plt.gcf()
fig.set_figheight(5)
fig.set_figwidth(10)
plt.show()

# %% [markdown]
# ## GBM

# %%
gs = GridSearchCV(
    gbm_model, 
    param_grid=param_grid, 
    n_jobs=-1, 
    cv=5, 
    scoring="neg_root_mean_squared_error"
)

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocesser',
#                                         ColumnTransformer(transformers=[('numerical',
#                                                                          'passthrough',
#                                                                          ['age',
#                                                                           'bmi',
#                                                                           'children']),
#                                                                         ('categorical',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          ['sex',
#                                                                           'smoker',
# ...

# %%
print(gs.best_params_)
print(gs.best_score_)
# Out:
# {'model__max_depth': 110, 'model__max_features': 3, 'model__min_samples_leaf': 5, 'model__min_samples_split': 10, 'model__n_estimators': 100}
# -5358.4854896992965

# %%
gbm_model.set_params(**gs.best_params_)
# Out:
# Pipeline(steps=[('preprocesser',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['age', 'bmi', 'children']),
#                                                  ('categorical',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('model',
#                  GradientBoostingRegressor(max_depth=110, max_features=3,
#                                            min_samples_leaf=5,
#                                            min_samples_split=10))])

# %%
gbm_model.get_params("model")
# Out:
# {'memory': None,
#  'steps': [('preprocesser',
#    ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                     ['age', 'bmi', 'children']),
#                                    ('categorical',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     ['sex', 'smoker', 'region'])])),
#   ('model',
#    GradientBoostingRegressor(max_depth=110, max_features=3, min_samples_leaf=5,
#                              min_samples_split=10))],
#  'verbose': False,
#  'preprocesser': ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                   ['age', 'bmi', 'children']),
#                                  ('categorical',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
# ...

# %%
gbm_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocesser',
#                  ColumnTransformer(transformers=[('numerical', 'passthrough',
#                                                   ['age', 'bmi', 'children']),
#                                                  ('categorical',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('model',
#                  GradientBoostingRegressor(max_depth=110, max_features=3,
#                                            min_samples_leaf=5,
#                                            min_samples_split=10))])

# %%
gbm_pred = gbm_model.predict(X_test)

# %%
shap.plots.partial_dependence(
    feature, 
    gbm_model.named_steps["model"].predict,
    shap_lr_df,
    ice=False,
    model_expected_value=True, 
    feature_expected_value=True
)

# %%
gbm_explainer = shap.TreeExplainer(gbm_model.named_steps["model"])
gbm_shap_values = gbm_explainer(shap_lr_df)

# %%
gbm_shap_values.base_values = gbm_shap_values.base_values[:, 0]

# %%
shap.plots.waterfall(gbm_shap_values[idx], max_display=14, show=False)
fig = plt.gcf()
fig.set_figheight(5)
fig.set_figwidth(10)
plt.show()
